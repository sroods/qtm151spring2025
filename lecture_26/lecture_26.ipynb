# %% [markdown]
# # <span style="color:darkblue"> Lecture 26 - Essentials of Merging in SQL </span>
#
# <font size = "5">
#
# In this lecture we will cover some additional topics <br>
# regarding merging of datasets in SQL.
#
# SQL in 100 seconds:
#
# https://www.youtube.com/watch?v=zsjvFFKOm3c
#
# Overview of SQL:
#
# https://www.youtube.com/watch?v=27axs9dO7AE

# %% [markdown]
# # <span style="color:darkblue"> I. Import Libraries and Data </span>

# %% [markdown]
# <font size = "5">
#
# Import libraries

# %%
# psycogpg2 helps us process SQL commands to send to the server
# sqlalchemy facilitates establishing a connection with the server

import pandas as pd
from sqlalchemy import create_engine
from   sqlalchemy.engine import URL
from   sqlalchemy import text

# %% [markdown]
# <font size = "5">
#
# Connect to SQL server
#
# - In the default instructions we set <br>
# the password to "12345" in windows and <br>
# no password for Mac
# - ADJUST code accordingly!

# %%
# Use the connection details to your server
# These are the default settings.
# "postgresql" is a fixed argument
# If you have a different host,database, username, or password,
# change the corresponding connection details


url_server = URL.create(
    "postgresql",
    host = 'localhost',
    database = 'postgres',
    username = 'postgres',
    port = 5432,
    password  = "12345")

connection = create_engine(url_server)

# %% [markdown]
# # <span style="color:darkblue"> II. SQL Review </span>
#
# <font size = "5">
#
# United States Congress dataset
#
# - Bills and actions
# - US congress members

# %% [markdown]
# <font size = "5">
#
# Read datasets into Python

# %%
bills_actions       = pd.read_csv("data_raw/bills_actions.csv")
bills_subjects      = pd.read_csv("data_raw/bills_subjects.csv")
us_congress_members = pd.read_csv("data_raw/us_congress_members.csv")

# %% [markdown]
# <font size = "5">
#
# Upload to SQL

# %%
bills_actions.to_sql('bills_actions',
               con = connection,
               if_exists='replace',
               index=False)

bills_subjects.to_sql('bills_subjects',
               con = connection,
               if_exists='replace',
               index=False)

us_congress_members.to_sql('us_congress_members', 
             con = connection, 
             if_exists='replace',
             index=False)
# Out:
# 811

# %% [markdown]
# <font size = "5">
#
# Download from SQL Server

# %%
# Recall that "*" indicates that we should select all columns

data  = pd.read_sql(text('SELECT * \
                          FROM bills_actions;'), connection)

display(data)
# Out:
#       congress  bill_number bill_type  \
# 0          116         1029         s
# 1          116         1031         s
# 2          116         1160         s
# 3          116         1199         s
# 4          116         1208         s
# ...        ...          ...       ...
# 3298       116            9        hr
# 3299       116            9        hr
# 3300       116            9        hr
# 3301       116            9        hr
# 3302       116            9        hr
#
#                                                  action  \
# 0     S.Amdt.1274 Amendment SA 1274 proposed by Sena...
# 1     S.Amdt.2698 Amendment SA 2698 proposed by Sena...
# 2     S.Amdt.2659 Amendment SA 2659 proposed by Sena...
# 3     Committee on Health, Education, Labor, and Pen...
# 4     Committee on the Judiciary. Reported by Senato...
# ...                                                 ...
# 3298  H.Amdt.172 Amendment (A004) offered by Ms. Kus...
# 3299  H.Amdt.171 Amendment (A003) offered by Ms. Hou...
# 3300  H.Amdt.170 Amendment (A002) offered by Ms. Oma...
# 3301  POSTPONED PROCEEDINGS - At the conclusion of d...
# 3302  H.Amdt.169 Amendment (A001) offered by Mr. Esp...
#
#                                    main_action       object  member_id
# 0     senate amendment proposed (on the floor)    amendment        858
# 1     senate amendment proposed (on the floor)    amendment        675
# 2     senate amendment proposed (on the floor)    amendment        858
# 3        senate committee/subcommittee actions  senate bill       1561
# 4        senate committee/subcommittee actions  senate bill       1580
# ...                                        ...          ...        ...
# 3298                   house amendment offered    amendment         36
# 3299                   house amendment offered    amendment        186
# 3300                   house amendment offered    amendment        477
# 3301             other house amendment actions    amendment        393
# 3302                   house amendment offered    amendment          6
#
# [3303 rows x 7 columns]

# %% [markdown]
# <font size = "5">
#
# Try it yourself
#
# Download and display the "us_congress_members" dataset from SQL

# %%
# Write your own code

data  = pd.read_sql(text('SELECT full_name, last_name \
                          FROM us_congress_members;'), connection)

display(data)
# Out:
#                      full_name   last_name
# 0           A. Donald McEachin    McEachin
# 1                 Aaron Schock      Schock
# 2              Abby Finkenauer  Finkenauer
# 3     Abigail Davis Spanberger  Spanberger
# 4               Adam H. Putnam      Putnam
# ...                        ...         ...
# 1806             Wm. Lacy Clay        Clay
# 1807         Wyche, Jr. Fowler      Fowler
# 1808         Wyche, Jr. Fowler      Fowler
# 1809          Yvette D. Clarke      Clarke
# 1810               Zell Miller      Miller
#
# [1811 rows x 2 columns]

# %% [markdown]
# # <span style="color:darkblue"> III. Merge Dataset </span>
#
# <font size = "5">
#
# The following is an example of an entity relationship diagram (ERD)

# %% [markdown]
# <font size = "5">
#
# <img src="figures/rdb_us_congress.png" alt="drawing" width="650"/>
#
# - Here "member_id" is the PRIMARY KEY of the first dataset
# - We can check that with SQL commands

# %%
summary = pd.read_sql(text("SELECT COUNT(DISTINCT member_id) AS num_distinct, \
                           COUNT(*) AS num_members   \
                           FROM us_congress_members"),
                      connection)

summary
# Out:
#    num_distinct  num_members
# 0          1811         1811

# %% [markdown]
# <font size = "5">
#
# Merge two datasets
#
# - Similar to python
# - FROM is followed by the name of the primary dataset
# - LEFT is followed by the name of the secondary dataset
# - ON is the id variable used for merging

# %%
# Write your own code

example = pd.read_sql(text("SELECT * \
                            FROM bills_actions \
                            LEFT JOIN us_congress_members \
                            ON bills_actions.member_id = us_congress_members.member_id ;"),
                      connection)

example
# Out:
#       congress  bill_number bill_type  \
# 0          116            3        hr
# 1          116         7617        hr
# 2          116         1644        hr
# 3          116         4617        hr
# 4          116         3055        hr
# ...        ...          ...       ...
# 3298       116         1749         s
# 3299       116         4761        hr
# 3300       116         4739        hr
# 3301       116         3055        hr
# 3302       116         3469        hr
#
#                                                  action  \
# 0     H.Amdt.719 Amendment (A009) offered by Ms. Fin...
# 1     H.Amdt.870 Amendment (A012) offered by Ms. Fin...
# 2     H.Amdt.167 Amendment (A011) offered by Ms. Spa...
# 3     H.Amdt.651 Amendment (A014) offered by Ms. Spa...
# 4     H.Amdt.429 Amendment (A043) offered by Ms. Spa...
# ...                                                 ...
# 3298  Mr. Clay asked unanimous consent to discharge ...
# 3299  Ms. Clarke (NY) moved to suspend the rules and...
# 3300  Ms. Clarke (NY) moved to suspend the rules and...
# 3301  H.Amdt.401 Amendment (A015) offered by Ms. Cla...
# 3302  Ms. Clarke (NY) moved to suspend the rules and...
#
#                   main_action       object  member_id  member_id  \
# 0     house amendment offered    amendment          2          2
# 1     house amendment offered    amendment          2          2
# 2     house amendment offered    amendment          3          3
# 3     house amendment offered    amendment          3          3
# 4     house amendment offered    amendment          3          3
# ...                       ...          ...        ...        ...
# 3298      house floor actions  senate bill       1806       1806
# 3299      house floor actions   house bill       1809       1809
# 3300      house floor actions   house bill       1809       1809
# 3301  house amendment offered    amendment       1809       1809
# 3302      house floor actions   house bill       1809       1809
#
#                      full_name   last_name    member_title     state  \
# 0              Abby Finkenauer  Finkenauer  Representative      Iowa
# 1              Abby Finkenauer  Finkenauer  Representative      Iowa
# 2     Abigail Davis Spanberger  Spanberger  Representative  Virginia
# 3     Abigail Davis Spanberger  Spanberger  Representative  Virginia
# 4     Abigail Davis Spanberger  Spanberger  Representative  Virginia
# ...                        ...         ...             ...       ...
# 3298             Wm. Lacy Clay        Clay  Representative  Missouri
# 3299          Yvette D. Clarke      Clarke  Representative  New York
# 3300          Yvette D. Clarke      Clarke  Representative  New York
# 3301          Yvette D. Clarke      Clarke  Representative  New York
# 3302          Yvette D. Clarke      Clarke  Representative  New York
#
#       party_name chamber
# 0     Democratic   House
# 1     Democratic   House
# 2     Democratic   House
# 3     Democratic   House
# 4     Democratic   House
# ...          ...     ...
# 3298  Democratic   House
# 3299  Democratic   House
# 3300  Democratic   House
# 3301  Democratic   House
# 3302  Democratic   House
#
# [3303 rows x 14 columns]

# %% [markdown]
# # <span style="color:darkblue"> III. Examples of special cases </span>
#
# <font size = "5">
#
# Merging with multiple keys

# %%
# Write your own code


example = pd.read_sql(text("SELECT * \
                            FROM bills_actions \
                            LEFT JOIN bills_subjects \
                            ON  bills_actions.bill_number = bills_subjects.bill_number \
                                AND bills_actions.bill_type = bills_subjects.bill_type;"),
                      connection)

example
# Out:
#         congress  bill_number bill_type  \
# 0            116            1     hjres
# 1            116            1     hjres
# 2            116            1     hjres
# 3            116            1     hjres
# 4            116            1     hjres
# ...          ...          ...       ...
# 154019       116         9051        hr
# 154020       116         9051        hr
# 154021       116         9051        hr
# 154022       116         9051        hr
# 154023       116         9051        hr
#
#                                                    action  \
# 0       Ms. Granger moved to recommit to the Committee...
# 1       Ms. Granger moved to recommit to the Committee...
# 2       Ms. Granger moved to recommit to the Committee...
# 3       Ms. Granger moved to recommit to the Committee...
# 4       Ms. Granger moved to recommit to the Committee...
# ...                                                   ...
# 154019  Mr. Neal moved to suspend the rules and pass t...
# 154020  Mr. Neal moved to suspend the rules and pass t...
# 154021  Mr. Neal moved to suspend the rules and pass t...
# 154022  Mr. Neal moved to suspend the rules and pass t...
# 154023  Mr. Neal moved to suspend the rules and pass t...
#
#                                  main_action                  object  \
# 0       house committee/subcommittee actions  house joint resolution
# 1       house committee/subcommittee actions  house joint resolution
# 2       house committee/subcommittee actions  house joint resolution
# 3       house committee/subcommittee actions  house joint resolution
# 4       house committee/subcommittee actions  house joint resolution
# ...                                      ...                     ...
# 154019                   house floor actions              house bill
# 154020                   house floor actions              house bill
# 154021                   house floor actions              house bill
# 154022                   house floor actions              house bill
# 154023                   house floor actions              house bill
#
#         member_id  congress  bill_number bill_type  \
# 0             693     116.0          1.0     hjres
# 1             693     116.0          1.0     hjres
# 2             693     116.0          1.0     hjres
# 3             693     116.0          1.0     hjres
# 4             693     116.0          1.0     hjres
# ...           ...       ...          ...       ...
# 154019       1671     116.0       9051.0        hr
# 154020       1671     116.0       9051.0        hr
# 154021       1671     116.0       9051.0        hr
# 154022       1671     116.0       9051.0        hr
# 154023       1671     116.0       9051.0        hr
#
#                                              bill_subject
# 0                                          Appropriations
# 1                   State and local government operations
# 2       Government employee pay, benefits, personnel m...
# 3                       Immigration status and procedures
# 4                                 State and local finance
# ...                                                   ...
# 154019              Cardiovascular and respiratory health
# 154020                  Infectious and parasitic diseases
# 154021       Tax administration and collection, taxpayers
# 154022                                 Income tax credits
# 154023         Emergency medical services and trauma care
#
# [154024 rows x 11 columns]

# %% [markdown]
# <font size = 5>
# Subsetting specific columns of the secondary dataset before merging <br>
# via "common table expressions"

# %%
# The first part of the code creates an 
# intermediate dataset (temporarily stored but deleted after the query)
# The rest of the code just merges the data.

example = pd.read_sql(text("WITH intermediate_dataset AS ( \
                                SELECT member_id, full_name \
                                FROM us_congress_members \
                            ) \
                            SELECT * \
                            FROM bills_actions \
                            LEFT JOIN intermediate_dataset \
                            ON bills_actions.member_id = intermediate_dataset.member_id ;"),
                      connection)

example
# Out:
#       congress  bill_number bill_type  \
# 0          116         1029         s
# 1          116         1031         s
# 2          116         1160         s
# 3          116         1199         s
# 4          116         1208         s
# ...        ...          ...       ...
# 3298       116            9        hr
# 3299       116            9        hr
# 3300       116            9        hr
# 3301       116            9        hr
# 3302       116            9        hr
#
#                                                  action  \
# 0     S.Amdt.1274 Amendment SA 1274 proposed by Sena...
# 1     S.Amdt.2698 Amendment SA 2698 proposed by Sena...
# 2     S.Amdt.2659 Amendment SA 2659 proposed by Sena...
# 3     Committee on Health, Education, Labor, and Pen...
# 4     Committee on the Judiciary. Reported by Senato...
# ...                                                 ...
# 3298  H.Amdt.172 Amendment (A004) offered by Ms. Kus...
# 3299  H.Amdt.171 Amendment (A003) offered by Ms. Hou...
# 3300  H.Amdt.170 Amendment (A002) offered by Ms. Oma...
# 3301  POSTPONED PROCEEDINGS - At the conclusion of d...
# 3302  H.Amdt.169 Amendment (A001) offered by Mr. Esp...
#
#                                    main_action       object  member_id  \
# 0     senate amendment proposed (on the floor)    amendment        858
# 1     senate amendment proposed (on the floor)    amendment        675
# 2     senate amendment proposed (on the floor)    amendment        858
# 3        senate committee/subcommittee actions  senate bill       1561
# 4        senate committee/subcommittee actions  senate bill       1580
# ...                                        ...          ...        ...
# 3298                   house amendment offered    amendment         36
# 3299                   house amendment offered    amendment        186
# 3300                   house amendment offered    amendment        477
# 3301             other house amendment actions    amendment        393
# 3302                   house amendment offered    amendment          6
#
#       member_id           full_name
# 0           858     Mitch McConnell
# 1           675         Josh Hawley
# 2           858     Mitch McConnell
# 3          1561     Lamar Alexander
# 4          1580      Lindsey Graham
# ...         ...                 ...
# 3298         36       Ann M. Kuster
# 3299        186    Chrissy Houlahan
# 3300        477          Ilhan Omar
# 3301        393  Frank, Jr. Pallone
# 3302          6   Adriano Espaillat
#
# [3303 rows x 9 columns]

# %% [markdown]
# # <span style="color:darkblue"> V. (Optional) Additional Resources </span>
#
#
# <font size = "5">
#
#
# Introduction to databases:
#
# https://www.youtube.com/watch?v=wR0jg0eQsZA
#
# Introduction to Entity Relationship Diagrams
#
# https://www.youtube.com/watch?v=wR0jg0eQsZA

# %% [markdown]
# <font size = 5>
#
# Examples of advanced techniques
#
# https://medium.com/@techsuneel99/20-advanced-sql-techniques-with-practical-examples-b47490d9896d

# %% [markdown]
# # <span style="color:darkblue"> VI. Concluding Remarks </span>
#
#
# <font size = "5">
#
# A few things to take away from this class:
#
# (1) Modularity:
#
# - Python is built over smaller components
# - It depends on a notion of objects and functions applied <br>
# to those objects.
# - Emphasized "chaining" of operations.
#
# (2) Specialization:
#
# - Python is great at math, logic, and data analysis.
# - SQL is great at updating, managing and retrieving datasets, <br>
# particularly at a corporate level.
# - Integrations across languages is straightforward!
#
# (2) Extensibility
#
# - We only covered a fraction of the things that Python can do.
# - New functionalities rely on the basic principles covered in the class!
# - Keep practicing new things! :)

# %% [markdown]
# # <span style="color:darkblue"> Thank you to our fantastic TAs! </span>

# %% [markdown]
# # <span style="color:darkblue"> V. Where to go from here?  </span>

# %% [markdown]
# <font size = "5">
#
# More courses in QTM!
#
# https://quantitative.emory.edu/undergraduate/courses.html

# %% [markdown]
# <font size = "5">
#
# Data Camp
#
# https://www.datacamp.com/

# %% [markdown]
# <font size = "5">
#
# Course era:
#
# https://www.coursera.org/specializations/python

# %% [markdown]
# <font size = "5">
#
# Prepare for coding interviews:
#
# https://leetcode.com/

# %% [markdown]
# # <span style="color:darkblue"> Thank you for a wonderful semester! </span>
